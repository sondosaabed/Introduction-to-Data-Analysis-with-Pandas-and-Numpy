# %% [markdown]
# # Pandas Groupby
# The [groupby](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html) method lets you group by one or more columns and perform specific aggregation calculations on DataFrames. We will experiment with this new method in the notebook below.

# %%
# Load `census_income_data.csv`
import pandas as pd

df = pd.read_csv("census_income_data.csv")

# %%
# view the columns available
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
# calculate the mean values for all numeric columns
df.mean(numeric_only=True)
# Out:
# age                   38.581647
# fnlwgt            189778.366512
# education-num         10.080679
# capital-gain        1077.648844
# capital-loss          87.303830
# hours-per-week        40.437456
# dtype: float64

# %%
# groupby "workclass" to see the different mean values for all numeric columns
df.groupby("workclass").mean(numeric_only=True)
# Out:
#                          age         fnlwgt  education-num  capital-gain  \
# workclass
#  Federal-gov       42.590625  185221.243750      10.973958    833.232292
#  Local-gov         41.751075  188639.712852      11.042045    880.202580
#  Never-worked      20.571429  225989.571429       7.428571      0.000000
#  Private           36.797585  192764.114734       9.879714    889.217792
#  Self-emp-inc      46.017025  175981.344086      11.137097   4875.693548
#  Self-emp-not-inc  44.969697  175608.641480      10.226289   1886.061787
#  State-gov         39.436055  184136.613251      11.375963    701.699538
#  Without-pay       47.785714  174267.500000       9.071429    487.857143
#
#                    capital-loss  hours-per-week
# workclass
#  Federal-gov         112.268750       41.379167
#  Local-gov           109.854276       40.982800
#  Never-worked          0.000000       28.428571
#  Private              80.008724       40.267096
#  Self-emp-inc        155.138889       48.818100
#  Self-emp-not-inc    116.631641       44.421881
#  State-gov            83.256549       39.031587
#  Without-pay           0.000000       32.714286

# %%
# groupby "workclass" and "race" to see the different mean values for all numeric columns
df.groupby(["workclass", "race"]).mean(numeric_only=True)
# Out:
#                                              age         fnlwgt  \
# workclass         race
#  Federal-gov       Amer-Indian-Eskimo  42.842105   90124.105263
#                    Asian-Pac-Islander  40.931818  118511.750000
#                    Black               41.633136  218892.331361
#                    Other               33.000000  129977.285714
#                    White               43.002774  184442.266297
#  Local-gov         Amer-Indian-Eskimo  38.694444   94324.750000
#                    Asian-Pac-Islander  39.846154  181518.282051
#                    Black               41.173611  225112.763889
#                    Other               36.000000  217902.900000
#                    White               41.988372  184497.970930
#  Never-worked      Black               25.000000  319483.500000
#                    White               18.800000  188592.000000
#  Private           Amer-Indian-Eskimo  34.305263  131002.857895
#                    Asian-Pac-Islander  36.716690  161942.253857
#                    Black               36.712316  229010.500460
#                    Other               33.441315  200253.342723
#                    White               36.871367  190354.471604
#  Self-emp-inc      Amer-Indian-Eskimo  44.000000  171968.500000
#                    Asian-Pac-Islander  43.391304  138773.391304
#                    Black               42.478261  235677.217391
#                    Other               40.000000  117540.000000
#                    White               46.244231  176595.568269
#  Self-emp-not-inc  Amer-Indian-Eskimo  42.125000  137440.750000
#                    Asian-Pac-Islander  41.643836  179037.095890
#                    Black               43.000000  239957.956989
#                    Other               39.333333  168458.777778
#                    White               45.202391  173365.095218
#  State-gov         Amer-Indian-Eskimo  45.533333  111839.266667
#                    Asian-Pac-Islander  38.034483  154849.379310
#                    Black               39.125786  227722.037736
#                    Other               28.000000  202432.750000
#                    White               39.516008  180162.839925
#  Without-pay       Asian-Pac-Islander  67.000000  137192.000000
#                    Black               21.000000  232719.000000
#                    White               48.416667  172486.166667
#
#                                        education-num  capital-gain  \
# workclass         race
#  Federal-gov       Amer-Indian-Eskimo      10.368421      0.000000
#                    Asian-Pac-Islander      12.045455   2813.454545
#                    Black                   10.236686    547.396450
#                    Other                   10.571429      0.000000
#                    White                   11.101248    809.432732
#  Local-gov         Amer-Indian-Eskimo      10.250000    304.222222
#                    Asian-Pac-Islander      11.743590    374.256410
#                    Black                   10.611111    904.586806
#                    Other                    9.700000    115.100000
#                    White                   11.122674    904.095349
#  Never-worked      Black                    9.500000      0.000000
#                    White                    6.600000      0.000000
#  Private           Amer-Indian-Eskimo       9.010526    785.036842
#                    Asian-Pac-Islander      10.712482   1315.124825
#                    Black                    9.255055    478.601103
#                    Other                    8.450704    135.568075
#                    White                    9.943362    928.908163
#  Self-emp-inc      Amer-Indian-Eskimo       9.500000   8954.500000
#                    Asian-Pac-Islander      12.108696   3336.152174
#                    Black                   10.826087   5904.434783
#                    Other                   10.200000  19999.800000
#                    White                   11.108654   4840.481731
#  Self-emp-not-inc  Amer-Indian-Eskimo       9.500000    451.041667
#                    Asian-Pac-Islander      11.041096   2187.178082
#                    Black                    9.892473   2371.677419
#                    Other                   12.888889  11921.888889
#                    White                   10.211358   1833.531597
#  State-gov         Amer-Indian-Eskimo      10.066667      0.000000
#                    Asian-Pac-Islander      12.534483    664.913793
#                    Black                   10.672956    567.547170
#                    Other                   10.500000   1922.000000
#                    White                   11.439736    729.108286
#  Without-pay       Asian-Pac-Islander       9.000000      0.000000
#                    Black                    9.000000      0.000000
#                    White                    9.083333    569.166667
#
#                                        capital-loss  hours-per-week
# workclass         race
#  Federal-gov       Amer-Indian-Eskimo      0.000000       40.315789
#                    Asian-Pac-Islander    310.750000       41.909091
#                    Black                  81.230769       40.769231
#                    Other                   0.000000       42.142857
#                    White                 111.479889       41.510402
#  Local-gov         Amer-Indian-Eskimo      0.000000       39.444444
#                    Asian-Pac-Islander     85.410256       39.256410
#                    Black                  73.201389       39.340278
#                    Other                 188.700000       41.700000
#                    White                 118.386628       41.325000
#  Never-worked      Black                   0.000000       40.000000
#                    White                   0.000000       23.800000
#  Private           Amer-Indian-Eskimo     37.721053       40.036842
#                    Asian-Pac-Islander     79.583450       39.936886
#                    Black                  53.183824       38.359375
#                    Other                  51.089202       39.103286
#                    White                  83.764069       40.508194
#  Self-emp-inc      Amer-Indian-Eskimo      0.000000       35.000000
#                    Asian-Pac-Islander    132.173913       50.086957
#                    Black                   0.000000       53.391304
#                    Other                 435.800000       69.400000
#                    White                 158.534615       48.588462
#  Self-emp-not-inc  Amer-Indian-Eskimo    144.250000       44.375000
#                    Asian-Pac-Islander    172.232877       47.849315
#                    Black                 124.107527       40.709677
#                    Other                   0.000000       48.333333
#                    White                 114.766866       44.447908
#  State-gov         Amer-Indian-Eskimo      0.000000       42.266667
#                    Asian-Pac-Islander     25.603448       35.413793
#                    Black                  53.660377       38.169811
#                    Other                   0.000000       34.500000
#                    White                  92.325800       39.329567
#  Without-pay       Asian-Pac-Islander      0.000000       12.000000
#                    Black                   0.000000       40.000000
#                    White                   0.000000       33.833333

# %%
# set as_index=False to keep "workclass" and "race" as non index values
# select just "capital-gain" to view only that column's mean
df.groupby(["workclass", "race"], as_index=False)["capital-gain"].mean()
# Out:
#             workclass                 race  capital-gain
# 0         Federal-gov   Amer-Indian-Eskimo      0.000000
# 1         Federal-gov   Asian-Pac-Islander   2813.454545
# 2         Federal-gov                Black    547.396450
# 3         Federal-gov                Other      0.000000
# 4         Federal-gov                White    809.432732
# 5           Local-gov   Amer-Indian-Eskimo    304.222222
# 6           Local-gov   Asian-Pac-Islander    374.256410
# 7           Local-gov                Black    904.586806
# 8           Local-gov                Other    115.100000
# 9           Local-gov                White    904.095349
# 10       Never-worked                Black      0.000000
# 11       Never-worked                White      0.000000
# 12            Private   Amer-Indian-Eskimo    785.036842
# 13            Private   Asian-Pac-Islander   1315.124825
# 14            Private                Black    478.601103
# 15            Private                Other    135.568075
# 16            Private                White    928.908163
# 17       Self-emp-inc   Amer-Indian-Eskimo   8954.500000
# 18       Self-emp-inc   Asian-Pac-Islander   3336.152174
# 19       Self-emp-inc                Black   5904.434783
# 20       Self-emp-inc                Other  19999.800000
# 21       Self-emp-inc                White   4840.481731
# 22   Self-emp-not-inc   Amer-Indian-Eskimo    451.041667
# 23   Self-emp-not-inc   Asian-Pac-Islander   2187.178082
# 24   Self-emp-not-inc                Black   2371.677419
# 25   Self-emp-not-inc                Other  11921.888889
# 26   Self-emp-not-inc                White   1833.531597
# 27          State-gov   Amer-Indian-Eskimo      0.000000
# 28          State-gov   Asian-Pac-Islander    664.913793
# 29          State-gov                Black    567.547170
# 30          State-gov                Other   1922.000000
# 31          State-gov                White    729.108286
# 32        Without-pay   Asian-Pac-Islander      0.000000
# 33        Without-pay                Black      0.000000
# 34        Without-pay                White    569.166667
